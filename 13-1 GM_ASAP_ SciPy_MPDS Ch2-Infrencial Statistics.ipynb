# %% [markdown]
# # Getting the larger picture from inferential statistics

# %% [markdown]
# The SciPy package of Python provides useful functions to perform statistical computations. You can install it from http://www.scipy.org/. The following commands helps in plotting the binomial distribution:

# %%
# %matplotlib inline
from scipy import stats
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Binomial Distribution

# %% [markdown]
# Plotting the binomial distribution

# %% [markdown]
# The binom function in the SciPy package helps generate binomial distributions
# and the necessary statistics related to it. If you observe the preceding commands,
# there are parts of it that are from the matplotlib, which we'll use right now to plot
# the binomial distribution.

# %%
x = [0, 1, 2, 3, 4, 5, 6]
n, p = 6, 0.5
rv = stats.binom(n, p)
print(rv.pmf(x))
# Out:
# [0.015625 0.09375  0.234375 0.3125   0.234375 0.09375  0.015625]

# %%
fig, ax = plt.subplots(1, 1)
x = [0, 1, 2, 3, 4, 5, 6]
n, p = 6, 0.5
rv = stats.binom(n, p)
ax.vlines(x, 0, rv.pmf(x), colors='k', linestyles='-', lw=1,
          label='Probablity')
ax.legend(loc='best', frameon=False)
plt.xlabel('No. of instances')
plt.ylabel('Probability')
plt.show()

# %%
for i in x:
    print(rv.pmf(i))
# Out:
# 0.01562500000000012
# 0.09375000000000003
# 0.23437500000000003
# 0.31249999999999983
# 0.234375
# 0.09375000000000003
# 0.015625

# %% [markdown]
# Plotting the Binomial Distribution with more attempts

# %%
fig, ax = plt.subplots(1, 1)
x = range(100)
n, p = 100, 0.5
rv = stats.binom(n, p)
ax.vlines(x, 0, rv.pmf(x), colors='k', linestyles='-', lw=1,
          label='Probablity')

ax.legend(loc='best', frameon=False)
plt.xlabel('No. of instances')
plt.ylabel('Probability')
plt.show()

# %% [markdown]
# Plotting the Binomial Distribution with less probability

# %%
fig, ax = plt.subplots(1, 1)
x = range(100)
n, p = 100, 0.4
rv = stats.binom(n, p)
ax.vlines(x, 0, rv.pmf(x), colors='k', linestyles='-', lw=1,
          label='Probablity')

ax.legend(loc='best', frameon=False)
plt.xlabel('No. of instances')
plt.ylabel('Probability')
plt.show()

# %% [markdown]
# Plotting the Binomial Distribution with more probability

# %%
fig, ax = plt.subplots(1, 1)
x = range(100)
n, p = 100, 0.6
rv = stats.binom(n, p)
ax.vlines(x, 0, rv.pmf(x), colors='k', linestyles='-', lw=1,
          label='Probablity')

ax.legend(loc='best', frameon=False)
plt.xlabel('No. of instances')
plt.ylabel('Probability')
plt.show()

# %% [markdown]
# Plotting the binomial distribution with many instances

# %%
fig, ax = plt.subplots(1, 1)
x = range(1000)
n, p = 1000, 0.5
rv = stats.binom(n, p)
ax.vlines(x, 0, rv.pmf(x), colors='k', linestyles='-', lw=1,
          label='Probablity')

ax.legend(loc='best', frameon=False)
plt.xlabel('No. of instances')
plt.ylabel('Probability')
plt.show()

# %% [markdown]
# ## Poisson Probability

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The probability of getting 23 when on average it is 20

# %%
rv = stats.poisson(20)
rv.pmf(23)
# Out:
# 0.06688147366240117

# %% [markdown]
# With the Poisson function, we define the mean value, which is 20 cars. The rv.pmf
# function gives the probability, which is around 6%, that 23 cars will pass the bridge.

# %% [markdown]
# ## Z-Score

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Generating classroom scores and viewing the distribution

# %%
# Mean=50
#SD=10

# %%
classscore = np.random.normal(50, 10, 60).round()
#classscore
plt.hist(classscore, 20)
plt.xlabel('No. of students')
print(classscore)
plt.show()
# Out:
# [69. 44. 75. 54. 70. 55. 41. 64. 57. 49. 47. 48. 57. 72. 55. 43. 42. 59.
#  48. 66. 59. 43. 47. 36. 47. 48. 65. 51. 31. 51. 44. 46. 46. 64. 39. 44.
#  55. 48. 36. 63. 51. 48. 36. 48. 55. 46. 48. 67. 55. 67. 64. 48. 44. 65.
#  59. 66. 56. 63. 57. 47.]

# %% [markdown]
# Finding the z-score of each of the marks

# %%
stats.zscore(classscore)
# Out:
# array([ 0.52895589,  1.56274589,  0.42557689, -0.81497112,  0.52895589,
#        -0.71159212, -0.19469712, -0.71159212,  0.63233489,  0.21881888,
#        -0.60821312,  0.11543988,  0.32219789, -0.29807612, -0.40145512,
#         0.11543988, -0.29807612,  0.11543988, -0.50483412, -1.22848713,
#         0.42557689, -0.60821312, -1.02172912, -1.33186613,  0.01206088,
#         1.04585089,  0.42557689, -0.81497112,  0.63233489,  0.83909289,
#        -1.95214013,  0.32219789,  0.11543988,  1.35598789, -1.02172912,
#         0.32219789,  0.32219789, -0.40145512, -1.74538213,  2.9066729 ,
#         0.73571389,  2.3897779 , -1.33186613,  1.7695039 , -0.29807612,
#         0.11543988,  1.04585089, -0.71159212,  0.52895589, -1.02172912,
#         1.66612489, -1.12510812, -2.36565613,  0.52895589,  0.52895589,
#         0.83909289, -0.91835012, -0.81497112, -0.50483412,  0.32219789])

# %% [markdown]
# # Finding the probability of values higher than 1.334 z-score

# %%
prob = 1 - stats.norm.cdf(1.334)
prob
# Out:
# 0.0911019282653599

# %% [markdown]
# Finding the Z-score of top 20% marks

# %%
stats.norm.ppf(0.80)
# Out:
# 0.8416212335729143

# %% [markdown]
# Finding the value of the Z-score of 0.84

# %%
(0.84 * classscore.std())
# Out:
# 7.6421407995404005

# %%
(0.84 * classscore.std()) + classscore.mean()
# Out:
# 57.28518063720775

# %% [markdown]
# ## P-Value

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Let's understand this concept with an example where the null hypothesis is that it is
# common for students to score 68 marks in mathematics.
# Let's define the significance level at 5%. If the p-value is less than 5%, then the null
# hypothesis is rejected and it is not common to score 68 marks in mathematics.
# Let's get the z-score of 68 marks:

# %%
zscore = ( 68 - classscore.mean() ) / classscore.std()
zscore
# Out:
# 1.9463612064838816

# %% [markdown]
# Let's convert the probability to z-score

# %%
prob = 1 - stats.norm.cdf(zscore)
prob
# Out:
# 0.025805683049102024

# %% [markdown]
# ## Confidence Interval

# %% [markdown]
# Let’s try to understand this concept by using an example. Lets take the height of every man in Kenya and determine with 95% confidence interval the average of height of Kenyan men at a national level.
# Let’s take 50 men and their height in centimeters

# %%
height_data = np.array([186.0, 180.0, 195.0, 189.0, 191.0, 177.0, 161.0, 177.0, 192.0, 182.0, 185.0, 192.0,
                        173.0, 172.0, 191.0, 184.0, 193.0, 182.0, 190.0, 185.0, 181.0, 188.0, 179.0, 188.0,
                        170.0, 179.0, 180.0, 189.0, 188.0, 185.0, 170.0, 197.0, 187.0, 182.0, 173.0, 179.0,
                        184.0, 177.0, 190.0, 174.0, 203.0, 206.0, 173.0, 169.0, 178.0, 201.0, 198.0, 166.0,
                        171.0, 180.0])

plt.hist(height_data, 30)
plt.xlabel('Height')
plt.show()

# %% [markdown]
# The mean of the distribution is

# %%
height_data.mean()
# Out:
# 183.24

# %% [markdown]
# So the average height of a man from the sample is 183.4 cm
#
# To determine the confidence interval, we’ll now define the standard error of the mean.
#
# The standard error of the mean is the deviation of the sample mean can have from the population mean. It is defined as the standard deviation by the root of the number of elements.

# %%
stats.sem(height_data)
# Out:
# 1.3787187190005248

# %% [markdown]
# So there is a standard error of the mean of 1.38 cm. So the lower and upper limit of the confidence interval will be
#
# <b>Lower Limit</b>: 183.24 + (1.96 * 1.38) = 185.94
#
# <b>Upper Limit</b>: 183.24 - (1.96*1.38) =  180.53
#
# 1.96 standard deviation covers 95% of area in the normal distribution
#
# So we can confidently say that the population mean lies in between 180.53 cm and 185.94 cm of height.
#
# Lets assume, we take a sample of 50 people, record their height and then repeat this process 30 times. We can then plot the averages of each sample and observe the distribution.

# %%
average_height = []
for i in range(30):
    sample50 = np.random.normal(183, 10, 50).round()
    average_height.append(sample50.mean())

plt.hist(average_height, 10)
plt.xlabel('Height')
plt.show()

# %% [markdown]
# You can observe that the mean ranges from 180 to 187 cm when we simulated the average height of 50 sample men which was taken 30 times.
#
# Let’s, see what happens when we 1000 sample men and repeat the process 30 times

# %%
average_height = []
for i in range(30):
    sample1000 = np.random.normal(183, 10, 1000).round()
    average_height.append(sample1000.mean())

plt.hist(average_height, 10)
plt.xlabel('Height')
plt.show()

# %% [markdown]
# As you can see, the height varies from 182 and to 185. What does this mean?
# It means that as sample size increases, the standard error of the mean decreases which also means that the confidence interval becomes more narrow and we can tell with certainty that at what interval the population mean would lie which is pretty cool

# %% [markdown]
# ## Type 1 and Type 2 errors
# Type 1 error is a type of error that occurs when there is a rejection of the null
# hypothesis when it is actually true. This kind of error is also called an error
# of the first kind and is equivalent to false positives.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Let's understand this concept using an example. There is a new drug that is being
# developed and it needs to be tested on whether it is effective in combating diseases.
# The null hypothesis is that it is not effective in combating diseases.
# The significance level is kept at 5% so that the null hypothesis can be accepted
# confidently 95% of the time. However, 5% of the time, we'll accept the rejecttion
# of the hypothesis although it had to be accepted, which means that even though
# the drug is ineffective, it is assumed to be effective.
# The Type 1 error is controlled by controlling the significance level, which is alpha.
# Alpha is the highest probability to have a Type 1 error. The lower the alpha, the
# lower will be the Type 1 error.
# The Type 2 error is the kind of error that occurs when we do not reject a null
# hypothesis that is false. This error is also called the error of the second kind
# and is equivalent to a false negative.
# This kind of error occurs in a drug scenario when the drug is assumed to be
# ineffective but is actually it is effective.
# These errors can be controlled one at a time. If one of the errors is lowered, then
# the other one increases. It depends on the use case and the problem statement that
# the analysis is trying to address, and depending on it, the appropriate error should
# reduce. In the case of this drug scenario, typically, a Type 1 error should be lowered
# because it is better to ship a drug that is confidently effective.

# %% [markdown]
# ## Correlation

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# . Let’s take the mileage and horsepower of various cars and see if there is a relation between it. This can be achieved using pearsonr function in the scipy package

# %%
mpg = [21.0, 21.0, 22.8, 21.4, 18.7, 18.1, 14.3, 24.4, 22.8, 19.2, 17.8, 16.4, 17.3, 15.2, 10.4, 10.4, 14.7, 32.4, 30.4,
       33.9, 21.5, 15.5, 15.2, 13.3, 19.2, 27.3, 26.0, 30.4, 15.8, 19.7, 15.0, 21.4]
hp = [110, 110, 93, 110, 175, 105, 245, 62, 95, 123, 123, 180, 180, 180, 205, 215, 230, 66, 52, 65, 97, 150, 150, 245,
      175, 66, 91, 113, 264, 175, 335, 109]

stats.pearsonr(mpg, hp)

plt.scatter(mpg, hp)
plt.xlabel('mpg')
plt.ylabel('hp')
plt.show()

# %%
stats.pearsonr(mpg,hp)
# Out:
# PearsonRResult(statistic=-0.7761683718265863, pvalue=1.7878352541210788e-07)

# %% [markdown]
# The 1st value of the output gives the correlation between the horsepower and the mileage and 2nd value gives the p-value.
#
# So, the 1st value tells us that it is highly negatively correlated and the p-value tells us that there is significant correlation between them.

# %%
stats.spearmanr(mpg,hp)
# Out:
# (-0.89466464574996252, 5.085969430924539e-12)

# %% [markdown]
# We can see that the spearman correlation is -0.89 and the p-value is significant.
#
# Let’s do an experiment in which we introduce few outlier values in the data and see how Pearson and Spearman correlation gets affected.

# %%
mpg = [21.0, 21.0, 22.8, 21.4, 18.7, 18.1, 14.3, 24.4, 22.8, 19.2, 17.8, 16.4, 17.3, 15.2, 10.4, 10.4, 14.7, 32.4, 30.4,
       33.9, 21.5, 15.5, 15.2, 13.3, 19.2, 27.3, 26.0, 30.4, 15.8, 19.7, 15.0, 21.4, 120, 3]
hp = [110, 110, 93, 110, 175, 105, 245, 62, 95, 123, 123, 180, 180, 180, 205, 215, 230, 66, 52, 65, 97, 150, 150, 245,
      175, 66, 91, 113, 264, 175, 335, 109, 30, 600]

plt.scatter(mpg, hp)
plt.xlabel('mpg')
plt.ylabel('hp')
plt.show()

# %%
stats.pearsonr(mpg, hp)
# Out:
# PearsonRResult(statistic=-0.4741530489143548, pvalue=0.004612216794734842)

# %%
stats.spearmanr(mpg, hp)
# Out:
# SpearmanrResult(correlation=-0.9122218433726569, pvalue=6.055168165798113e-14)

# %% [markdown]
# We can clearly see that the pearson correlation has got drastically affected due to the outliers which is from a correlation of 0.89 to a  0.47.
#
# The spearman correlation did not got affected much as it is based on the order rather than the value.

# %% [markdown]
# ## T-Test

# %% [markdown]
# T-test is used for comparing the population mean against a sample or comparing the population mean of two distributions with sample size less than 30 and when you don’t know the population’s standard deviation.
#
#
# Let’s do a T-test on two classes that given a mathematics and have 10 students in each class

# %%
class1_score = np.array([45.0, 40.0, 49.0, 52.0, 54.0, 64.0, 36.0, 41.0, 42.0, 34.0])
class2_score = np.array([75.0, 85.0, 53.0, 70.0, 72.0, 93.0, 61.0, 65.0, 65.0, 72.0])

stats.ttest_ind(class1_score, class2_score)
# Out:
# Ttest_indResult(statistic=-5.458195056848408, pvalue=3.482072285015316e-05)

# %% [markdown]
# The 1st value in the output is the calculated t-statistics whereas the 2nd value is the p-value and p-value shows that the two distributions are not identical

# %% [markdown]
# ## Chi-Square

# %% [markdown]
# Chi-Square for Goodness of fit
#
# Chi-Square test can be used to test whether the observed data differs significantly from the expected data.
#
# Let’s take the example of a dice.
#
# The dice is rolled 36 times and the probability that each face should turn up is ⅙. So the expected distribution is as follows

# %%
expected = np.array([6, 6, 6, 6, 6, 6])
observed = np.array([7, 5, 3, 9, 6, 6])

stats.chisquare(observed, expected)
# Out:
# Power_divergenceResult(statistic=3.333333333333333, pvalue=0.6487423586675934)

# %% [markdown]
# The 1st value is the chi-square value and the 2nd value is the p-value which is very high. This means that the null hypothesis is valid and observed is similar to the expected

# %% [markdown]
# ## Chi-Square Test of Independence
#
# The Chi-Square Test of independence is a statistical test to determine if two categorical variables are independent of each other or not
#
# Let’s take the following example to see if there is a preference between gender and genre of a book

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
men_women = np.array([[100, 120, 60],[350, 200, 90]])
stats.chi2_contingency(men_women)
# Out:
# (28.362103174603167,
#  6.9382117170577439e-07,
#  2,
#  array([[ 136.95652174,   97.39130435,   45.65217391],
#        [ 313.04347826,  222.60869565,  104.34782609]]))

# %% [markdown]
# The 1st value is the chi-square value.
#
# The 2nd value is the p-value which is very small which means that there is an association between the gender and genre of the book they read.
#
# The 3rd value is the degrees of freedom
#
# The 4th value which is an array is the expected frequencies

# %% [markdown]
# ## ANOVA

# %% [markdown]
# Analysis of Variance is a statistical method used to test differences between two or more means.
#
# This test basically compares the means between groups and determines whether any  of those 	means are significantly different from each other.

# %% [markdown]
# ### H0 :μ1 = μ2 = μ3 =......= μk

# %% [markdown]
# ANOVA is a test that cannot tell you which group is significantly different from each other.
#
#
# Lets take the height of men who are from three different countries and see if their heights are significantly different from others

# %%
country1 = np.array([ 176.,  179.,  180.,  188.,  187.,  184.,  171.,  201.,  172.,
        181.,  192.,  187.,  178.,  178.,  180.,  199.,  185.,  176.,
        207.,  177.,  160.,  174.,  176.,  192.,  189.,  187.,  183.,
        180.,  181.,  200.,  190.,  187.,  175.,  179.,  181.,  183.,
        171.,  181.,  190.,  186.,  185.,  188.,  201.,  192.,  188.,
        181.,  172.,  191.,  201.,  170.,  170.,  192.,  185.,  167.,
        178.,  179.,  167.,  183.,  200.,  185.])

country2 = np.array([ 177.,  165.,  175.,  172.,  179.,  192.,  169.,  185.,  187.,
        167.,  162.,  165.,  188.,  194.,  187.,  175.,  163.,  178.,
        197.,  172.,  175.,  185.,  176.,  171.,  172.,  186.,  168.,
        178.,  191.,  192.,  175.,  189.,  178.,  181.,  170.,  182.,
        166.,  189.,  196.,  192.,  189.,  171.,  185.,  198.,  181.,
        167.,  184.,  179.,  178.,  193.,  179.,  177.,  181.,  174.,
        171.,  184.,  156.,  180.,  181.,  187.])

country3 = np.array([ 191.,  190.,  191.,  185.,  190.,  184.,  173.,  175.,  200.,
        190.,  191.,  184.,  167.,  194.,  195.,  174.,  171.,  191.,
        174.,  177.,  182.,  184.,  176.,  180.,  181.,  186.,  179.,
        176.,  186.,  176.,  184.,  194.,  179.,  171.,  174.,  174.,
        182.,  198.,  180.,  178.,  200.,  200.,  174.,  202.,  176.,
        180.,  163.,  159.,  194.,  192.,  163.,  194.,  183.,  190.,
        186.,  178.,  182.,  174.,  178.,  182.])

stats.f_oneway(country1,country2,country3)
# Out:
# (2.9852039682631375, 0.053079678812747652)

# %% [markdown]
# The 1st value of the output gives the F-value and the 2nd value gives the p-value. Since the p-value is greater than 5% by a small margin so we can that the mean of the heights in the three countries are not significantly different from each other.
